# %%
import pandas as pd
from pathlib import Path

# %%
df_greenhouse = pd.read_csv(
    Path("./data/greenhouse_gas.csv"),
    index_col = "Year"
)

# %%
df_total = df_greenhouse.loc[(df_greenhouse["VAR"]=="TOTAL")]
df_ghg = df_total.loc[(df_total["POL"]=="GHG")]
df_combine = pd.DataFrame({
    "Austria":df_ghg[(df_ghg["Country"]=="Austria")]["Value"],"Australia":df_ghg[(df_ghg["Country"]=="Australia")]["Value"]
})
df_combine
# Out:
#         Austria   Australia
# Year
# 1990  78420.485  423672.225
# 1991  82082.332  423733.064
# 1992  75469.271  427426.084
# 1993  75709.189  428337.072
# 1994  75958.303  428818.221
# 1995  79237.977  437276.554
# 1996  82452.589  443928.268
# 1997  82116.229  456015.976
# 1998  81432.850  469751.524
# 1999  79898.365  476391.987
# 2000  80129.431  487777.763
# 2001  84064.719  495604.310
# 2002  85815.059  499190.485
# 2003  91306.715  500599.962
# 2004  90985.234  517726.514
# 2005  92147.286  524211.489
# 2006  89728.782  528038.422
# 2007  86983.941  534417.835
# 2008  86440.211  537262.312
# 2009  79779.073  540381.618
# 2010  84336.718  535549.224
# 2011  82127.026  537205.495
# 2012  79432.380  539511.055
# 2013  79817.174  530311.914
# 2014  76238.670  524709.397
# 2015  78462.233  533063.832
# 2016  79471.008  542287.865
# 2017  81862.497  549330.022
# 2018  78627.637  549731.942
# 2019  79842.253  545152.518

# %%
df_ghg[(df_ghg["Country"]=="Australia")]["Value"]
# Out:
# Year
# 1990    423672.225
# 1991    423733.064
# 1992    427426.084
# 1993    428337.072
# 1994    428818.221
# 1995    437276.554
# 1996    443928.268
# 1997    456015.976
# 1998    469751.524
# 1999    476391.987
# 2000    487777.763
# 2001    495604.310
# 2002    499190.485
# 2003    500599.962
# 2004    517726.514
# 2005    524211.489
# 2006    528038.422
# 2007    534417.835
# 2008    537262.312
# 2009    540381.618
# 2010    535549.224
# 2011    537205.495
# 2012    539511.055
# 2013    530311.914
# 2014    524709.397
# 2015    533063.832
# 2016    542287.865
# 2017    549330.022
# 2018    549731.942
# 2019    545152.518
# Name: Value, dtype: float64

# %%
df_climate = pd.read_csv(
    Path("./data/GlobalTemperatures.csv")
)
df_climate["dt"] = pd.to_datetime(df_climate["dt"])
df_climate.set_index("dt",inplace=True)
df_climate.tail()
# Out:
#             LandAverageTemperature  LandAverageTemperatureUncertainty  \
# dt
# 2015-08-01                  14.755                              0.072
# 2015-09-01                  12.999                              0.079
# 2015-10-01                  10.801                              0.102
# 2015-11-01                   7.433                              0.119
# 2015-12-01                   5.518                              0.100
#
#             LandMaxTemperature  LandMaxTemperatureUncertainty  \
# dt
# 2015-08-01              20.699                          0.110
# 2015-09-01              18.845                          0.088
# 2015-10-01              16.450                          0.059
# 2015-11-01              12.892                          0.093
# 2015-12-01              10.725                          0.154
#
#             LandMinTemperature  LandMinTemperatureUncertainty  \
# dt
# 2015-08-01               9.005                          0.170
# ...

# %%
df_climate["LandAverageTemperatureUncertainty"].groupby(by=[df_climate.index.year]).mean().plot()
# Out:
# <AxesSubplot:xlabel='dt'>
